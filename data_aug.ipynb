# %% [markdown]
# <a href="https://colab.research.google.com/github/mezahirecebov/data_aug/blob/main/data_aug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

from tensorflow.keras import layers
import cv2 as cv

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
  layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
imageOrigin=cv.imread("/content/ac2a6258-ce5d-11eb-b317-38f9d35ea60f.png")
image = tf.expand_dims(imageOrigin, 0)
plt.imshow(imageOrigin)

# %%
plt.figure(figsize=(10, 10))
for i in range(9):
  augmented_image = data_augmentation(image)
  ax = plt.subplot(3, 3, i + 1)
  plt.imshow(augmented_image[0])
  # plt.axis("off")
